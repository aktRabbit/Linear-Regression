# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../data/insurance.csv")

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
target = "charges"

# %%
y=df[target]
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
# 6        8240.58960
# 7        7281.50560
# 8        6406.41070
# 9       28923.13692
# 10       2721.32080
# 11      27808.72510
# 12       1826.84300
# 13      11090.71780
# 14      39611.75770
# 15       1837.23700
# 16      10797.33620
# 17       2395.17155
# 18      10602.38500
# 19      36837.46700
# 20      13228.84695
# 21       4149.73600
# 22       1137.01100
# 23      37701.87680
# 24       6203.90175
# 25      14001.13380
# 26      14451.83515
# 27      12268.63225
# 28       2775.19215
# 29      38711.00000
#            ...
# 1308    33900.65300
# 1309     6875.96100
# 1310     6940.90985
# 1311     4571.41305
# 1312     4536.25900
# 1313    36397.57600
# 1314    18765.87545
# 1315    11272.33139
# 1316     1731.67700
# 1317     1163.46270
# 1318    19496.71917
# 1319     7201.70085
# 1320     5425.02335
# 1321    28101.33305
# 1322    12981.34570
# 1323    43896.37630
# 1324     4239.89265
# 1325    13143.33665
# 1326     7050.02130
# 1327     9377.90470
# 1328    22395.74424
# 1329    10325.20600
# 1330    12629.16560
# 1331    10795.93733
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 6 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 62.8+ KB

# %%
x = df

# %%
df
# Out:
#       age  gender     bmi  children smoker     region
# 0      19  female  27.900         0    yes  southwest
# 1      18    male  33.770         1     no  southeast
# 2      28    male  33.000         3     no  southeast
# 3      33    male  22.705         0     no  northwest
# 4      32    male  28.880         0     no  northwest
# 5      31  female  25.740         0     no  southeast
# 6      46  female  33.440         1     no  southeast
# 7      37  female  27.740         3     no  northwest
# 8      37    male  29.830         2     no  northeast
# 9      60  female  25.840         0     no  northwest
# 10     25    male  26.220         0     no  northeast
# 11     62  female  26.290         0    yes  southeast
# 12     23    male  34.400         0     no  southwest
# 13     56  female  39.820         0     no  southeast
# 14     27    male  42.130         0    yes  southeast
# 15     19    male  24.600         1     no  southwest
# 16     52  female  30.780         1     no  northeast
# 17     23    male  23.845         0     no  northeast
# 18     56    male  40.300         0     no  southwest
# 19     30    male  35.300         0    yes  southwest
# 20     60  female  36.005         0     no  northeast
# 21     30  female  32.400         1     no  southwest
# 22     18    male  34.100         0     no  southeast
# 23     34  female  31.920         1    yes  northeast
# 24     37    male  28.025         2     no  northwest
# 25     59  female  27.720         3     no  southeast
# 26     63  female  23.085         0     no  northeast
# 27     55  female  32.775         2     no  northwest
# 28     23    male  17.385         1     no  northwest
# 29     31    male  36.300         2    yes  southwest
# ...   ...     ...     ...       ...    ...        ...
# 1308   25  female  30.200         0    yes  southwest
# 1309   41    male  32.200         2     no  southwest
# 1310   42    male  26.315         1     no  northwest
# 1311   33  female  26.695         0     no  northwest
# 1312   34    male  42.900         1     no  southwest
# 1313   19  female  34.700         2    yes  southwest
# 1314   30  female  23.655         3    yes  northwest
# 1315   18    male  28.310         1     no  northeast
# 1316   19  female  20.600         0     no  southwest
# 1317   18    male  53.130         0     no  southeast
# 1318   35    male  39.710         4     no  northeast
# 1319   39  female  26.315         2     no  northwest
# 1320   31    male  31.065         3     no  northwest
# 1321   62    male  26.695         0    yes  northeast
# 1322   62    male  38.830         0     no  southeast
# 1323   42  female  40.370         2    yes  southeast
# 1324   31    male  25.935         1     no  northwest
# 1325   61    male  33.535         0     no  northeast
# 1326   42  female  32.870         0     no  northeast
# 1327   51    male  30.030         1     no  southeast
# 1328   23  female  24.225         2     no  northeast
# 1329   52    male  38.600         2     no  southwest
# 1330   57  female  25.740         2     no  southeast
# 1331   23  female  33.400         0     no  southwest
# 1332   52  female  44.700         3     no  southwest
# 1333   50    male  30.970         3     no  northwest
# 1334   18  female  31.920         0     no  northeast
# 1335   18  female  36.850         0     no  southeast
# 1336   21  female  25.800         0     no  southwest
# 1337   61  female  29.070         0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
# 29                   0                 1
# ...                ...               ...
# 1308                 0                 1
# 1309                 0                 1
# 1310                 0                 0
# 1311                 0                 0
# 1312                 0                 1
# 1313                 0                 1
# 1314                 0                 0
# 1315                 0                 0
# 1316                 0                 1
# 1317                 1                 0
# 1318                 0                 0
# 1319                 0                 0
# 1320                 0                 0
# 1321                 0                 0
# 1322                 1                 0
# 1323                 1                 0
# 1324                 0                 0
# 1325                 0                 0
# 1326                 0                 0
# 1327                 1                 0
# 1328                 0                 0
# 1329                 0                 1
# 1330                 1                 0
# 1331                 0                 1
# 1332                 0                 1
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 8 columns]

# %%
from sklearn import model_selection

# %%
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y,test_size=0.5,random_state=1)

# %%
from sklearn import linear_model

# %%
est = linear_model.LinearRegression()

# %%
est.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_train_pred = est.predict(x_train)

# %%
y_test_pred = est.predict(x_test)

# %%
residual = y_train_pred - y_train
plt.scatter(y_train, residual)
plt.xlabel("Actual")
plt.ylabel("Residual")
plt.title("Residual plot")
# Out:
# Text(0.5, 1.0, 'Residual plot')

# %%
plt.hist(residual)
# Out:
# (array([  1.,   5.,  10.,  19.,  14.,  79., 101., 344.,  38.,  58.]),
#  array([-29128.95276931, -24985.06756443, -20841.18235955, -16697.29715467,
#         -12553.41194979,  -8409.52674491,  -4265.64154003,   -121.75633515,
#           4022.12886974,   8166.01407462,  12309.8992795 ]),
#  <a list of 10 Patch objects>)

# %%
SSE_train = ((y_train_pred - y_train) ** 2).sum()
SSE_test = ((y_test_pred - y_test) ** 2).sum()

# %%
MSE_train = ((y_train_pred - y_train) ** 2).mean()
MSE_test = ((y_test_pred - y_test) ** 2).mean()

# %%
SST = ((y_train.mean() - y_train) ** 2).sum()

# %%
SSE_train/SST
# Out:
# 0.24332228986175147

# %%
r2 = 1 - SSE_train/SST
r2
# Out:
# 0.7566777101382485

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_train,y_train_pred)
# Out:
# 0.7566777101382485

# %%
metrics.r2_score(y_test,y_test_pred)
# Out:
# 0.7422238674970716

# %%
metrics.mean_squared_error(y_train,y_train_pred)
# Out:
# 36776731.92299899

# %%
metrics.mean_squared_error(y_test,y_test_pred)
# Out:
# 36552122.149179704

# %%
est.coef_
# Out:
# array([  265.82987251,   295.2915036 ,   472.9285994 ,    58.72030618,
#        24264.18881778,  -677.91844323,  -841.30839662, -1376.58942338])

# %%
pd.DataFrame({"feature": x.columns, "coefficient": est.coef_})
# Out:
#             feature   coefficient
# 0               age    265.829873
# 1               bmi    295.291504
# 2          children    472.928599
# 3       gender_male     58.720306
# 4        smoker_yes  24264.188818
# 5  region_northwest   -677.918443
# 6  region_southeast   -841.308397
# 7  region_southwest  -1376.589423

# %%
x
# Out:
#       age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 0      19  27.900         0            0           1                 0
# 1      18  33.770         1            1           0                 0
# 2      28  33.000         3            1           0                 0
# 3      33  22.705         0            1           0                 1
# 4      32  28.880         0            1           0                 1
# 5      31  25.740         0            0           0                 0
# 6      46  33.440         1            0           0                 0
# 7      37  27.740         3            0           0                 1
# 8      37  29.830         2            1           0                 0
# 9      60  25.840         0            0           0                 1
# 10     25  26.220         0            1           0                 0
# 1327   51  30.030         1            1           0                 0
# 1328   23  24.225         2            0           0                 0
# 1329   52  38.600         2            1           0                 0
# 1330   57  25.740         2            0           0                 0
# 1331   23  33.400         0            0           0                 0
# 1332   52  44.700         3            0           0                 0
# 1333   50  30.970         3            1           0                 1
# 1334   18  31.920         0            0           0                 0
# 1335   18  36.850         0            0           0                 0
# 1336   21  25.800         0            0           0                 0
# 1337   61  29.070         0            0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# 5                    1                 0
# 6                    1                 0
# 7                    0                 0
# 8                    0                 0
# 9                    0                 0
# 10                   0                 0
# 11                   1                 0
# 12                   0                 1
# 13                   1                 0
# 14                   1                 0
# 15                   0                 1
# 16                   0                 0
# 17                   0                 0
# 18                   0                 1
# 19                   0                 1
# 20                   0                 0
# 21                   0                 1
# 22                   1                 0
# 23                   0                 0
# 24                   0                 0
# 25                   1                 0
# 26                   0                 0
# 27                   0                 0
# 28                   0                 0
# 29                   0                 1
# ...                ...               ...
# 1308                 0                 1
# 1309                 0                 1
# 1310                 0                 0
# 1311                 0                 0
# 1312                 0                 1
# 1313                 0                 1
# 1314                 0                 0
# 1315                 0                 0
# 1316                 0                 1
# 1317                 1                 0
# 1318                 0                 0
# 1319                 0                 0
# 1320                 0                 0
# 1321                 0                 0
# 1322                 1                 0
# 1323                 1                 0
# 1324                 0                 0
# 1325                 0                 0
# 1326                 0                 0
# 1327                 1                 0
# 1328                 0                 0
# 1329                 0                 1
# 1330                 1                 0
# 1331                 0                 1
# 1332                 0                 1
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 8 columns]

# %%
plt.hist(x["bmi"])
# Out:
# (array([ 30., 127., 234., 319., 288., 195.,  96.,  32.,  14.,   3.]),
#  array([15.96 , 19.677, 23.394, 27.111, 30.828, 34.545, 38.262, 41.979,
#         45.696, 49.413, 53.13 ]),
#  <a list of 10 Patch objects>)

# %%
x["high_bmi"]=np.where(x["bmi"]>30,1,0)

# %%
x.head()
# Out:
#    age     bmi  children  gender_male  smoker_yes  region_northwest  \
# 0   19  27.900         0            0           1                 0
# 1   18  33.770         1            1           0                 0
# 2   28  33.000         3            1           0                 0
# 3   33  22.705         0            1           0                 1
# 4   32  28.880         0            1           0                 1
#
#    region_southeast  region_southwest  high_bmi
# 0                 0                 1         0
# 1                 1                 0         1
# 2                 1                 0         1
# 3                 0                 0         0
# 4                 0                 0         0

# %%
x["age_group"] = np.where(x.age>60, 1, 0)

# %%
from sklearn import preprocessing

# %%
poly = preprocessing.PolynomialFeatures(degree=2,include_bias=False)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 10 columns):
# age                 1338 non-null int64
# bmi                 1338 non-null float64
# children            1338 non-null int64
# gender_male         1338 non-null uint8
# smoker_yes          1338 non-null uint8
# region_northwest    1338 non-null uint8
# region_southeast    1338 non-null uint8
# region_southwest    1338 non-null uint8
# high_bmi            1338 non-null int32
# age_group           1338 non-null int32
# dtypes: float64(1), int32(2), int64(2), uint8(5)
# memory usage: 48.4 KB

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x.values.astype("float")
                                    , y , test_size = 0.3, random_state = 1)

# %%
x_train = poly.fit_transform(x_train)
x_test = poly.fit_transform(x_test)

# %%
scaler = preprocessing.StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
est = linear_model.SGDRegressor(random_state=1, eta0=0.001, tol=1e-5, learning_rate="constant"
                            , max_iter= 10000)

# %%
est.fit(x_train, y_train)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#        eta0=0.001, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='constant', loss='squared_loss', max_iter=10000,
#        n_iter=None, n_iter_no_change=5, penalty='l2', power_t=0.25,
#        random_state=1, shuffle=True, tol=1e-05, validation_fraction=0.1,
#        verbose=0, warm_start=False)

# %%
y_train_pred = est.predict(x_train)
y_test_pred = est.predict(x_test)

print("r2 train", metrics.r2_score(y_train, y_train_pred))
print("r2 test", metrics.r2_score(y_test, y_test_pred))

print("rmse train", np.sqrt(metrics.mean_squared_error(y_train, y_train_pred)))
print("rmse test", np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# r2 train 0.8318608479146061
# r2 test 0.866664592295433
# rmse train 0.3772563476716206
# rmse test 0.33490280446978365

# %% [markdown]
# ### Creating same code using pipeline

# %%
y_train
# Out:
# 744      9.085594
# 363      7.862412
# 10       7.908873
# 970      9.278246
# 634      9.147544
# 554      9.791377
# 314     10.458489
# 419     10.273342
# 525      9.348591
# 1041     7.441145
# 649      9.427945
# 1306     9.687525
# 790      8.641572
# 1044     9.340848
# 104      8.517963
# 1295     7.583136
# 370      9.504132
# 495      7.584276
# 1162     9.850254
# 903      9.002798
# 125      8.127227
# 694      8.182559
# 979      8.494751
# 1223    10.170674
# 1251     7.124128
# 529      7.443079
# 1018     9.433107
# 1139    10.515932
# 1011     9.839895
# 1097     7.423349
#           ...
# 1031    10.701531
# 141      8.157814
# 1110     9.351180
# 753      9.378714
# 1001    10.447927
# 1239     8.082846
# 580      9.466067
# 562      7.821652
# 398      9.615034
# 668     10.730077
# 252     10.697854
# 907      8.940331
# 468     10.055733
# 914      8.567412
# 357      9.171634
# 1278    10.019582
# 1300    11.044407
# 1202     7.628189
# 1305     7.809792
# 508      8.020998
# 749      8.026990
# 129      8.713155
# 144      9.940108
# 960      7.912096
# 847      7.798956
# 715      9.404835
# 905      8.425997
# 1096    10.706412
# 235      9.875307
# 1061     9.354806
# Name: charges, Length: 936, dtype: float64

# %%
from sklearn import pipeline

# %%
pipe = pipeline.Pipeline([

    ("est",linear_model.SGDRegressor(random_state=1, eta0=0.001, tol=1e-5
                            , learning_rate="constant"
                            , max_iter= 10000))
])

# %%
pipe.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('est', SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#        eta0=0.001, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='constant', loss='squared_loss', max_iter=10000,
#        n_iter=None, n_iter_no_change=5, penalty='l2', power_t=0.25,
#        random_state=1, shuffle=True, tol=1e-05, validation_fraction=0.1,
#        verbose=0, warm_start=False))])

# %%
y_train_pred = pipe.predict(x_train)
y_test_pred = pipe.predict(x_test)

# %%
y_train_pred = pipe.predict(x_train)
y_test_pred = pipe.predict(x_test)

print("r2 train", metrics.r2_score(y_train, y_train_pred))
print("r2 test", metrics.r2_score(y_test, y_test_pred))

print("rmse train", np.sqrt(metrics.mean_squared_error(y_train, y_train_pred)))
print("rmse test", np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# r2 train 0.8318608479146061
# r2 test 0.866664592295433
# rmse train 0.3772563476716206
# rmse test 0.33490280446978365

# %%
import pickle

# %%
with open("model.pkl", "wb") as f:
    pickle.dump(pipe, f)

# %%
with open("model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(memory=None,
#      steps=[('est', SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#        eta0=0.001, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='constant', loss='squared_loss', max_iter=10000,
#        n_iter=None, n_iter_no_change=5, penalty='l2', power_t=0.25,
#        random_state=1, shuffle=True, tol=1e-05, validation_fraction=0.1,
#        verbose=0, warm_start=False))])

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

print("r2 train", metrics.r2_score(y_train, y_train_pred))
print("r2 test", metrics.r2_score(y_test, y_test_pred))

print("rmse train", np.sqrt(metrics.mean_squared_error(y_train, y_train_pred)))
print("rmse test", np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# r2 train 0.8318608479146061
# r2 test 0.866664592295433
# rmse train 0.3772563476716206
# rmse test 0.33490280446978365
